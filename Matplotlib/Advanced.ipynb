# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Colored Scatterplots

# %%
iris = pd.read_csv("iris (1).csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# need to assign number to each species
# cmap for change
# aplha decide opacity
# c is for grouping for color
# s is for size based on the value

iris['Species_num'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species_num'], cmap = 'winter',
           alpha = 0.9)
plt.xlabel("Sepal Length (Cm)")
plt.ylabel("Petal Length(Cm)")
plt.colorbar() # tells the which color represent each category

# %%
# how to change size of the graph

plt.figure(figsize = (15, 7)) # This is to change the size of the graph

iris['Species_num'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor': 1, 'Iris-virginica': 2})

plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species_num'], cmap = 'winter',
           alpha = 0.9)
plt.xlabel("Sepal Length (Cm)")
plt.ylabel("Petal Length(Cm)")
plt.colorbar() # tells the which color represent each category

# %% [markdown]
# ## Annotation

# %%
batters = pd.read_csv("batter.csv")

# %%
sample_df = batters.head(100).sample(25, random_state = 5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
aplt.figure(figsize=(15, 7))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s = sample_df['runs'])
plt.xlabel("Average Run")
plt.ylabel("Strike Rate")
plt.title("Average Vs Strike Rate")

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i] + 0.3, sample_df['batter'].values[i],
            fontdict = {"size" : 12})

# %%
x = range(1, 5)
y = range(5, 9)

plt.scatter(x, y)
# three paramters are passed , x and y and name
plt.text(1, 5, 'Point 1')
plt.text(2, 6, 'Point 2')
plt.text(3, 7, 'Point 3')
plt.text(3.5, 8, 'Point 4', fontdict = {'size' : 12, 'color':'brown'})
# Out:
# Text(3.5, 8, 'Point 4')

# %% [markdown]
# # Plot Vertical and Horizontal Line

# %%
plt.figure(figsize=(15, 7))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s = sample_df['runs'])
plt.xlabel("Average Run")
plt.ylabel("Strike Rate")
plt.title("Average Vs Strike Rate")

plt.axhline(130, color = 'red')
plt.axhline(140, color = 'green')
plt.axvline(30, color = 'brown')

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i] + 0.3, sample_df['batter'].values[i],
            fontdict = {"size" : 12})

# %% [markdown]
# ## Subplots

# %%
# A diff way to plot graphs
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
fig, ax = plt.subplots(figsize = (16, 8))

ax.scatter(batters['avg'], batters['strike_rate'], color = 'red', marker = '+')
ax.set_title("Something")
ax.set_xlabel("Avg")
ax.set_ylabel("Strike Rate")

fig.show()
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_46989/2895882892.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (8, 8)) # if coordinate of axis is shared

ax[0, 0].scatter(batters['avg'], batters['strike_rate'], color = 'red', marker = '+')
ax[0, 0].set_title("Something")
ax[0, 0].set_xlabel("Avg")
ax[0, 0].set_ylabel("Strike Rate")

ax[0, 1].scatter(batters['avg'], batters['runs'], color = 'red', marker = '+')
ax[0, 1].set_title("Something")
ax[0, 1].set_xlabel("Avg")
ax[0, 1].set_ylabel("Strike Rate")

ax[1, 0].hist(batters['avg'])
ax[1, 0].set_title("Something")
ax[1, 0].set_xlabel("Avg")
ax[1, 0].set_ylabel("Strike Rate")

ax[1, 1].hist(batters['runs'])
ax[1, 1].set_title("Something")
ax[1, 1].set_xlabel("Avg")
ax[1, 1].set_ylabel("Strike Rate")

fig.show()
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_46989/3683117170.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()

ax1 =  fig.add_subplot(221)

ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)

# %% [markdown]
# ## 3D Plots

# %%
figure = plt.figure()

ax = plt.subplot(projection = '3d')

ax.scatter3D(batters['runs'], batters['avg'], batters['strike_rate'])
ax.set_title('IPL batsman Analysis')

ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('Strike Rate')
# Out:
# Text(0.5, 0, 'Strike Rate')

# %% [markdown]
# # 3D line plot

# %%
x = [0, 0, 0]
y = [-1, 1, 1]
z = [2, 2, -2]

figure = plt.figure()

ax = plt.subplot(projection = '3d')
ax.scatter3D(x, y, z, s = [100,100, 100])
ax.plot3D(x, y, z, color = 'red')

# %% [markdown]
# # 3D Surface Plots

# %%
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

# %%
xx, yy = np.meshgrid(x, y)

# %%
z = xx**2 + yy**2

# %%
z
# Out:
# array([[200.        , 196.00040812, 192.08244057, ..., 192.08244057,
#         196.00040812, 200.        ],
#        [196.00040812, 192.00081624, 188.08284869, ..., 188.08284869,
#         192.00081624, 196.00040812],
#        [192.08244057, 188.08284869, 184.16488113, ..., 184.16488113,
#         188.08284869, 192.08244057],
#        ...,
#        [192.08244057, 188.08284869, 184.16488113, ..., 184.16488113,
#         188.08284869, 192.08244057],
#        [196.00040812, 192.00081624, 188.08284869, ..., 188.08284869,
#         192.00081624, 196.00040812],
#        [200.        , 196.00040812, 192.08244057, ..., 192.08244057,
#         196.00040812, 200.        ]])

# %%
fig = plt.figure(figsize = (16, 8))

ax = plt.subplot(projection = '3d')
p = ax.plot_surface(xx, yy, z , cmap = 'viridis')
fig.colorbar(p)
